# %% [markdown]
# # Question 1;
# Assuming that we have some email addresses in the "username@companyname.com" format, please write program
# to print the company name of a given email address. Both user names and company names are composed of letters
# only.
# Input Format:
# The first line of the input contains an email address.
# Output Format:
# Print the company name in single line.
# Example;
# Input:
# john@google.com
# Output:
# google

# %%
email=input("Enter your email address :")
e1= email.split("@")[1]
e2= e1.split(".")[0]


print(e2)
# Out:
# Enter your email address :pallavi@gmail.com
# gmail

# %% [markdown]
# # Question 2:
# Write a program that accepts a comma-separated sequence of words as input and prints the words in a comma
# separated sequence after sorting them alphabetically.
# Input Format:
# The first line of input contains words separated by the comma.
# Output Format:
# Print the sorted words separated by the comma.
# Example:
# Input:
# without,hello,bag,world
# Output:
# bag,hello,without,world

# %%
name=input("Enter words")
words=list(map(lambda x:x, name.split(",")))
words.sort()
print("Sorted sequence are : ", ','.join(words))
# Out:
# Enter wordsai,ds,py,ml
# Sorted sequence are :  ai,ds,ml,py

# %% [markdown]
# # Question 3
# Create your own Jupyter Notebook for Sets.
# Reference link: https://www.w3schools.com/python/python_sets.asp

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)

# Note: the set list is unordered, meaning: the items will appear in a random order.

# Refresh this page to see the change in the result.
# Out:
# {'apple', 'cherry', 'banana'}

# %% [markdown]
# # Question 4
# Given a list of n-1 numbers ranging from 1 to n, your task is to find the missing number. There are no duplicates.
# Input Format:
# The first line contains n-1 numbers with each number separated by a space.
# Output Format:
# Print the missing number
# Example:
# Input:1 2 4 6 3 7 8
# Output:5
# Explanation:
# In the above list of numbers 5 is missing and hence 5 is the input

# %%
def find_missing(lst): 
    return [x for x in range(lst[0], lst[-1]+1)  
                               if x not in lst] 
  
# Driver code 
lst = [1, 2, 4, 6, 7, 9, 10] 
print(find_missing(lst))
# Out:
# [3, 5, 8]

# %% [markdown]
# # Question 5
# With a given list L, write a program to print this list L after removing all duplicate values with original order reserved.
# Example:
# If the input list is
# 12 24 35 24 88 120 155 88 120 155
# Then the output should be
# 12 24 35 88 120 155

# %%
list1=[12,24, 35, 24, 88, 12,155, 88, 120, 155]
list2=[]

for n in list1:
    if n not in list2:
        list2.append(n)
print("List 1 : ", list1)
print("After removin duplicate : ", list2)
# Out:
# List 1 :  [12, 24, 35, 24, 88, 12, 155, 88, 120, 155]
# After removin duplicate :  [12, 24, 35, 88, 155, 120]
